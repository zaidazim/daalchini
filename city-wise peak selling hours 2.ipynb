# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.subplots as sp
import plotly.graph_objects as go

# %%
df = pd.read_csv('city_wise_hourly_sales.csv')

# %%
df.head(10)
# Out:
#   hour_of_day  city                                     product  qty_sold  \
# 0    12AM-1AM  Agra               13202 - Maaza Tetrapack Rs 10        11
# 1    12AM-1AM  Agra  12954 - Cadbury Dairy Milk Crispello Rs 10         4
# 2    12AM-1AM  Agra             13245 - Thumbs up Pop Can Rs 25         4
# 3    12AM-1AM  Agra         12770 - Parle G Gold Biscuits Rs 10         4
# 4    12AM-1AM  Agra        21147 - Haldirams Chips Pudina Treat         3
# 5     1AM-2AM  Agra           13253 - Coke Diet Can 180ml Rs 25         2
# 6     1AM-2AM  Agra              12483 - Sprite 250ml Pet Rs 20         2
# 7     1AM-2AM  Agra             13013 - ThumsUp 250ml Pet Rs 20         2
# 8     1AM-2AM  Agra              13743 - Fanta Can 180 ml Rs 25         2
# 9     1AM-2AM  Agra               13202 - Maaza Tetrapack Rs 10         1
#
#    city_hour_sales  product_rank
# 0               59             1
# 1               59             2
# 2               59             3
# 3               59             4
# 4               59             5
# 5               15             1
# 6               15             2
# 7               15             3
# 8               15             4
# 9               15             5

# %%
selected_cities = ['Chennai', 'Mumbai City', 'Kolkata', 'Pune', 'Jamnagar']

df_aggregated = df[df['city'].isin(selected_cities)]

# %%
# Assuming your aggregated data is stored in a DataFrame named 'df_aggregated'

# Create a color scale for products
color_scale = sns.color_palette("husl", n_colors=len(df_aggregated['product'].unique())).as_hex()

# Create subplots
fig = sp.make_subplots(rows=len(df_aggregated['city'].unique()), cols=1,
                       subplot_titles=[f'Hourly Sales by Product - {city}' for city in df_aggregated['city'].unique()],
                       shared_xaxes=True, vertical_spacing=0.1)

# Loop through each city and create a stacked bar chart
for i, city in enumerate(df_aggregated['city'].unique()):
    city_data = df_aggregated[df_aggregated['city'] == city]
    
    # Map each product to a color using the color scale
    color_mapping = dict(zip(city_data['product'].unique(), color_scale))
    city_data['color'] = city_data['product'].map(color_mapping)
    
    # Create the stacked bar chart for each city
    trace = go.Bar(x=city_data['hour_of_day'], y=city_data['qty_sold'], marker_color=city_data['color'],
                   hovertext=city_data['product'], showlegend=False)
    
    # Add the trace to the subplot
    fig.add_trace(trace, row=i + 1, col=1)

# Customize the layout
fig.update_layout(barmode='stack', yaxis_title='Quantity Sold', height=800)

# Set the angle for the x-axis title to be vertical
fig.update_xaxes(title_text='Hour of Day', tickangle=-90)

# Show the plot
fig.show()
# Out:
# C:\Users\zaida\AppData\Local\Temp\ipykernel_11020\2290105166.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\zaida\AppData\Local\Temp\ipykernel_11020\2290105166.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\zaida\AppData\Local\Temp\ipykernel_11020\2290105166.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\zaida\AppData\Local\Temp\ipykernel_11020\2290105166.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\zaida\AppData\Local\Temp\ipykernel_11020\2290105166.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <div>                            <div id="e877d420-1ba1-4a75-88c9-1c293cdcaadc" class="plotly-graph-div" style="height:800px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e877d420-1ba1-4a75-88c9-1c293cdcaadc")) {                    Plotly.newPlot(                        "e877d420-1ba1-4a75-88c9-1c293cdcaadc",                        [{"hovertext":["19102 - Horlicks Rs 5","15392 - Puzzles Party Mix Rs 10","18886 - A2B Thattai Rs 20","18884 - A2B Mini Murukku Rs 20","15718 - Too yumm veggie stick chili","18886 - A2B Thattai Rs 20","15392 - Puzzles Party Mix Rs 10","18884 - A2B Mini Murukku Rs 20","19102 - Horlicks Rs 5","19281 - A2b Rajapalayam Thatai Rs 20","15392 - Puzzles Party Mix Rs 10","18884 - A2B Mini Murukku Rs 20","18886 - A2B Thattai Rs 20","19102 - Horlicks Rs 5","17291 - Nestle KitKat Rs 30","18886 - A2B Thattai Rs 20","15392 - Puzzles Party Mix Rs 10","17514 - Pepsi Mirinda Rs 35","19102 - Horlicks Rs 5","15250 - Too Yumm American Cream And Onion Chips Rs 20","15392 - Puzzles Party Mix Rs 10","19102 - Horlicks Rs 5","18884 - A2B Mini Murukku Rs 20","15718 - Too yumm veggie stick chili","18886 - A2B Thattai Rs 20","15392 - Puzzles Party Mix Rs 10","19102 - Horlicks Rs 5","17616 - Rewynd Coated Peanuts Nut Crunch 32g Rs 10","14722 - Britannia Milk Bikis Rs 20","19281 - A2b Rajapalayam Thatai Rs 20","19102 - Horlicks Rs 5","18886 - A2B Thattai Rs 20","18884 - A2B Mini Murukku Rs 20","14722 - Britannia Milk Bikis Rs 20","20470 - Cadbury Dairy Milk","19102 - Horlicks Rs 5","14722 - Britannia Milk Bikis Rs 20","15392 - Puzzles Party Mix Rs 10","20330 - Britannia Jim Jam Pops Rs 20","17406 - Cracker Bee Milk Cookies Rs 30","14722 - Britannia Milk Bikis Rs 20","19102 - Horlicks Rs 5","17290 - Britannia Toastea Rs 10","17291 - Nestle KitKat Rs 30","19103 - Boost Rs 5","18884 - A2B Mini Murukku Rs 20","17291 - Nestle KitKat Rs 30","19102 - Horlicks Rs 5","18886 - A2B Thattai Rs 20","15491 - Too Yumm Karare Munchy Masala Rs 20","19102 - Horlicks Rs 5","18884 - A2B Mini Murukku Rs 20","18886 - A2B Thattai Rs 20","17291 - Nestle KitKat Rs 30","19103 - Boost Rs 5","19102 - Horlicks Rs 5","18884 - A2B Mini Murukku Rs 20","18886 - A2B Thattai Rs 20","14722 - Britannia Milk Bikis Rs 20","17291 - Nestle KitKat Rs 30","18884 - A2B Mini Murukku Rs 20","18886 - A2B Thattai Rs 20","19102 - Horlicks Rs 5","17291 - Nestle KitKat Rs 30","15250 - Too Yumm American Cream And Onion Chips Rs 20","18886 - A2B Thattai Rs 20","17291 - Nestle KitKat Rs 30","15248 - Too Yumm Chips Kashmiri Chilli Rs 29","15250 - Too Yumm American Cream And Onion Chips Rs 20","18884 - A2B Mini Murukku Rs 20","17291 - Nestle KitKat Rs 30","18884 - A2B Mini Murukku Rs 20","18886 - A2B Thattai Rs 20","19102 - Horlicks Rs 5","15248 - Too Yumm Chips Kashmiri Chilli Rs 29","18884 - A2B Mini Murukku Rs 20","17291 - Nestle KitKat Rs 30","18886 - A2B Thattai Rs 20","19102 - Horlicks Rs 5","20470 - Cadbury Dairy Milk","18884 - A2B Mini Murukku Rs 20","18886 - A2B Thattai Rs 20","17291 - Nestle KitKat Rs 30","14722 - Britannia Milk Bikis Rs 20","19102 - Horlicks Rs 5","19102 - Horlicks Rs 5","18886 - A2B Thattai Rs 20","18884 - A2B Mini Murukku Rs 20","17291 - Nestle KitKat Rs 30","15250 - Too Yumm American Cream And Onion Chips Rs 20","18886 - A2B Thattai Rs 20","17291 - Nestle KitKat Rs 30","18884 - A2B Mini Murukku Rs 20","19102 - Horlicks Rs 5","19281 - A2b Rajapalayam Thatai Rs 20","18886 - A2B Thattai Rs 20","17291 - Nestle KitKat Rs 30","18884 - A2B Mini Murukku Rs 20","19102 - Horlicks Rs 5","16168 - Britannia Little Heart","18886 - A2B Thattai Rs 20","17291 - Nestle KitKat Rs 30","18884 - A2B Mini Murukku Rs 20","16168 - Britannia Little Heart","15392 - Puzzles Party Mix Rs 10","18886 - A2B Thattai Rs 20","17291 - Nestle KitKat Rs 30","18884 - A2B Mini Murukku Rs 20","15250 -  ...
